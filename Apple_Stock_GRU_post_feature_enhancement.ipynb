# %% [markdown]
# ### ***Importing Necessary Libraries***

# %%
import pandas as pd
import numpy as np

from datetime import datetime

from sklearn.preprocessing import MinMaxScaler

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, GRU, Dense, Dropout

from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

from scikeras.wrappers import KerasRegressor
from sklearn.model_selection import GridSearchCV

from sklearn.metrics import mean_squared_error, mean_absolute_error
import matplotlib.pyplot as plt

# %% [markdown]
# ### ***Loading Dataset***

# %%
df = pd.read_csv("Datasets/AAPL_feature_enhancements.csv")

# %%
df.tail(2)
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 9821  2019-11-22  262.589996  263.179993  260.839996  261.779999  261.779999
# 9822  2019-11-25  262.709991  266.440002  262.519989  266.369995  266.369995
#
#           Volume  Day Gap      CPI  FED_FUNDS  ...  NASDAQ_Comp_Close  \
# 9821  16331300.0      1.0  257.879       1.55  ...        8519.879883
# 9822  21005100.0      3.0  257.879       1.55  ...        8632.490234
#
#       NASDAQ100_Adj_Close  SOX_Adj_Close  S&P500_Close  VIX_Adj_Close  \
# 9821          8272.049805    1690.790039   3110.290039          12.34
# 9822          8371.929688    1731.949951   3133.639893          11.87
#
#       sentiment_score  Vol_SMA_10  Vol_Ratio           OBV  sentiment_avail
# 9821         0.972565  22928970.0   0.712256  3.935792e+10                1
# 9822         0.982338  22983950.0   0.913903  3.937892e+10                1
#
# [2 rows x 21 columns]

# %% [markdown]
# ### ***Data Preprocessing***
#
# > #### ***1. Time-Series Conversion***

# %%
df = df.set_index(df['Date'])

# %%
df.drop(columns=["Date"], inplace=True)

# %%
df.index = pd.to_datetime(df.index)

# %%
df.head(2)
# Out:
#                 Open      High       Low     Close  Adj Close       Volume  \
# Date
# 1980-12-12  0.513393  0.515625  0.513393  0.513393   0.407747  117258400.0
# 1980-12-15  0.488839  0.488839  0.486607  0.486607   0.386473   43971200.0
#
#             Day Gap   CPI  FED_FUNDS       GDP  NASDAQ_Comp_Close  \
# Date
# 1980-12-12      0.0  86.4       18.9  7315.677         191.220001
# 1980-12-15      3.0  86.4       18.9  7315.677         194.020004
#
#             NASDAQ100_Adj_Close  SOX_Adj_Close  S&P500_Close  VIX_Adj_Close  \
# Date
# 1980-12-12                  0.0            0.0    129.229996            0.0
# 1980-12-15                  0.0            0.0    129.449997            0.0
#
#             sentiment_score   Vol_SMA_10  Vol_Ratio         OBV  \
# Date
# 1980-12-12              0.0  117258400.0   1.000000         0.0
# 1980-12-15              0.0   80614800.0   0.545448 -43971200.0
#
#             sentiment_avail
# Date
# 1980-12-12                0
# 1980-12-15                0

# %% [markdown]
# > ### ***2. Dataset Split***

# %%
train = df[df.index.year <= 2016]
test = df[df.index.year >= 2017]

# %%
print(f"train : {train.shape} - {(train.shape[0]/df.shape[0])*100:.2f} %")
print(f"test : {test.shape} - {(test.shape[0]/df.shape[0])*100:.2f} %")
# Out:
# train : (9093, 20) - 92.57 %
# test : (730, 20) - 7.43 %

# %% [markdown]
# > ### ***3. Feature Selection***

# %%
target_col  = 'Adj Close'
feature_col = [col for col in df.columns if col != target_col]

# %%
X_train, y_train = train[feature_col], train[target_col]
X_test, y_test   = test[feature_col], test[target_col]

# %%
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (9093, 19) (9093,)
# (730, 19) (730,)

# %% [markdown]
# > ### ***4. Scaling***
# > > *Min-Max Scalar*

# %%
# Load Min-Max Scalar

feature_scaler = MinMaxScaler()
target_scaler  = MinMaxScaler()

# %%
X_train_scaled = feature_scaler.fit_transform(train[feature_col])
y_train_scaled = target_scaler.fit_transform(train[[target_col]])

X_test_scaled = feature_scaler.transform(test[feature_col])
y_test_scaled = target_scaler.transform(test[[target_col]])

# %% [markdown]
# ## ***Model Building***
#
# > ### ***1. Creating Sequential Input/Output Data***

# %%
# Preparing 50-days rolling window (input) and 1-day, 3-day, 5-day forecasting horizon (output)

def create_multi_horizon_sequences(features, target, lookback=50, horizons=[1, 5, 10]):
    X_seq, y_seq = [], []
    max_horizon = max(horizons)

    for i in range(len(features) - lookback - max_horizon + 1):
        X_seq.append(features[i:i+lookback])
        y_seq.append([target[i+lookback+h-1] for h in horizons])
    
    return np.array(X_seq), np.array(y_seq)

# %%
lookback = 50
horizons = [1, 5, 10]

X_train_seq, y_train_seq = create_multi_horizon_sequences(X_train_scaled, y_train_scaled, lookback, horizons)
X_test_seq, y_test_seq   = create_multi_horizon_sequences(X_test_scaled, y_test_scaled, lookback, horizons)

# %%
print("Before reshape:")
print("X_train_seq:", X_train_seq.shape)
print("y_train_seq:", y_train_seq.shape)
print("X_test_seq:", X_test_seq.shape)
print("y_test_seq:", y_test_seq.shape)
# Out:
# Before reshape:
# X_train_seq: (9034, 50, 19)
# y_train_seq: (9034, 3, 1)
# X_test_seq: (671, 50, 19)
# y_test_seq: (671, 3, 1)

# %%
input_shape = (lookback, len(feature_col))
input_shape
# Out:
# (50, 19)

# %%
# Reshaping for RNN input

y_train_seq = y_train_seq.reshape(y_train_seq.shape[0], y_train_seq.shape[1])
y_test_seq = y_test_seq.reshape(y_test_seq.shape[0], y_test_seq.shape[1])

# %%
print("Train:", X_train_seq.shape, y_train_seq.shape)
print("Test:", X_test_seq.shape, y_test_seq.shape)
# Out:
# Train: (9034, 50, 19) (9034, 3)
# Test: (671, 50, 19) (671, 3)

# %%
# Ensure y is 2D
if y_train_seq.ndim == 2:
    #y_train_seq = y_train_seq.reshape(-1, 1)
    print(y_train_seq.shape)
# Out:
# (9034, 3)

# %% [markdown]
# > ### ***2. GRU***

# %%
# Building and Compiling GRU layers

def build_gru(rnn_type='GRU', gru_units=64, dropout_rate=0.2, learning_rate=0.001, input_shape=None):
    model = Sequential()
    model.add(Input(shape=input_shape))
    model.add(GRU(gru_units, activation="tanh"))
    model.add(Dropout(dropout_rate))
    model.add(Dense(y_train_seq.shape[1]))
    
    model.compile(optimizer=Adam(learning_rate=learning_rate), loss='mse')
    return model

# %%
early_stop = EarlyStopping(monitor='loss', 
                           patience=3, 
                           restore_best_weights=True,
                           verbose=1)

checkpoint = ModelCheckpoint(filepath="models/GRU_best_model_post_feature_enhancement.keras",
                             save_best_only=True,
                             save_weights_only=False,
                             monitor='loss')

# %%
# Wrapping the model

gru_regressor = KerasRegressor(model=build_gru, 
                               epochs=30, 
                               batch_size=32,
                               verbose=0,
                               callbacks=[early_stop, checkpoint])

# %% [markdown]
# > ### ***3. Hyperparameter Tuning with GridSearchCV***

# %%
# Defining Parameters

param_grid = {'model__gru_units': [32, 64],
              'model__dropout_rate': [0.1, 0.2],
              'model__learning_rate': [0.001, 0.01],
              'model__input_shape': [(X_train_seq.shape[1], X_train_seq.shape[2])]}

# %%
grid = GridSearchCV(gru_regressor, 
                    param_grid, 
                    cv=3, 
                    n_jobs=-1,
                    verbose=2)

# %% [markdown]
# ##  **Model Training**
#
# > ### ***Saving Best GRU Model***

# %%
best_gru = grid.fit(X_train_seq, y_train_seq)
# Out:
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# Epoch 7: early stopping
# Restoring model weights from the end of the best epoch: 4.

# %%
best_gru
# Out:
# GridSearchCV(cv=3,
#              estimator=KerasRegressor(batch_size=32, callbacks=[<keras.src.callbacks.early_stopping.EarlyStopping object at 0x000001E00CAC4C20>, <keras.src.callbacks.model_checkpoint.ModelCheckpoint object at 0x000001E00CAC4EC0>], epochs=30, model=<function build_gru at 0x000001E00CB98D60>, verbose=0),
#              n_jobs=-1,
#              param_grid={'model__dropout_rate': [0.1, 0.2],
#                          'model__gru_units': [32, 64],
#                          'model__input_shape': [(50, 19)],
#                          'model__learning_rate': [0.001, 0.01]},
#              verbose=2)

# %%
best_params = grid.best_params_
best_params
# Out:
# {'model__dropout_rate': 0.1,
#  'model__gru_units': 64,
#  'model__input_shape': (50, 19),
#  'model__learning_rate': 0.01}

# %%
best_score = grid.best_score_
best_score
# Out:
# np.float64(-2.6583113470762423)

# %%
cv_results = grid.cv_results_
print(cv_results.keys())
# Out:
# dict_keys(['mean_fit_time', 'std_fit_time', 'mean_score_time', 'std_score_time', 'param_model__dropout_rate', 'param_model__gru_units', 'param_model__input_shape', 'param_model__learning_rate', 'params', 'split0_test_score', 'split1_test_score', 'split2_test_score', 'mean_test_score', 'std_test_score', 'rank_test_score'])

# %% [markdown]
# ## ***Model Evaluation***

# %%
# Predicting Scaled Y_TEST data
y_pred_scaled = best_gru.predict(X_test_seq)

# %%
# Unscaling predicted values
y_pred = target_scaler.inverse_transform(y_pred_scaled)
y_true = target_scaler.inverse_transform(y_test_seq)

# %%
for i, h in enumerate(horizons):
    mse = mean_squared_error(y_true[:, i], y_pred[:, i])
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(y_true[:, i], y_pred[:, i])
    print(f"Horizon t+{h}  : MSE = {mse:.4f}, RMSE = {rmse:.4f}, MAE = {mae:.4f}")
# Out:
# Horizon t+1  : MSE = 165.6250, RMSE = 12.8695, MAE = 11.1362
# Horizon t+5  : MSE = 150.9389, RMSE = 12.2857, MAE = 9.7557
# Horizon t+10  : MSE = 328.2780, RMSE = 18.1184, MAE = 15.2038

# %% [markdown]
# ## ***GRU Prediction Plot***

# %%
# Getting dates for test data
y_dates = test.index[lookback + max(horizons) - 1:]
print(len(y_dates) == y_true.shape[0])
# Out:
# True

# %%
for i, h in enumerate(horizons):
    plt.figure(figsize=(12,4))
    plt.plot(y_dates, y_true[:, i], label="Actual Price", color="blue")
    plt.plot(y_dates, y_pred[:, i], label="Predicted Price", color="red", alpha=0.7)
    plt.title(f"GRU - Apple Adj Close Stock Prediction - Horizon t+{h} Days")
    plt.xlabel("Years")
    plt.ylabel("Adj Close")
    plt.legend()
    plt.show()
